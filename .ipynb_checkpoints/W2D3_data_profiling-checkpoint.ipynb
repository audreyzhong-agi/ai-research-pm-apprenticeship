# %%
import pandas as pd

df = pd.read_csv("data/product_events.csv")

print("Total rows:", len(df))
# Out:
# Total rows: 20000

# %%
total_revenue = df["revenue"].sum()

print("Total revenue:", total_revenue)
# Out:
# Total revenue: 1294374.58

# %%
event_counts = df["event_type"].value_counts()

print(event_counts)
# Out:
# event_type
# page_view           5991
# product_view        5944
# add_to_cart         3007
# purchase            2431
# checkout            1617
# remove_from_cart    1010
# Name: count, dtype: int64

# %%
print("Missing quantity:",df["quantity"].isna().sum())
print("Missing revenue:",df["revenue"].isna().sum())
# Out:
# Missing quantity: 14562
# Missing revenue: 0

# %%
print("Earliest event:",df["event_time"].min())
print("Latest event:",df["event_time"].max())
# Out:
# Earliest event: 2026-01-01T00:05:18+00:00
# Latest event: 2026-07-28T23:57:02+00:00
